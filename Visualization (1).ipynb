# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Importing Dataset

# %%
HouseHoldmasterdetail = pd.read_excel(r"D:\Interview Task\BARC\New Hire Assessment Programming Problem (1)\HouseHoldmasterdetail.xlsx")
HouseholIndividualDetails = pd.read_excel(r"D:\Interview Task\BARC\New Hire Assessment Programming Problem (1)\HouseholIndividualDetails.xlsx")
Viewership_data_day1 = pd.read_excel(r"D:\Interview Task\BARC\New Hire Assessment Programming Problem (1)\Viewership data day1.xlsx")
Viewership_data_day2 = pd.read_excel(r"D:\Interview Task\BARC\New Hire Assessment Programming Problem (1)\Viewership data day2.xlsx")
Viewership_data_day3 = pd.read_excel(r"D:\Interview Task\BARC\New Hire Assessment Programming Problem (1)\Viewership data day3.xlsx")

# %% [markdown]
# ### HouseHoldmasterdetail

# %%
HouseHoldmasterdetail
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 1     5076      New York      19
# 2     5123      New York      23
# 3     5142        Dallas       4
# 4     5143        Dallas      23
# ..     ...           ...     ...
# 164   9881  San Franisco      13
# 165   9898      Auckland      13
# 166   9950        Dallas      13
# 167   9952       NewPort      13
# 168   9957      New York       2
#
# [169 rows x 3 columns]

# %%
HouseHoldmasterdetail["Cities"].unique()
# Out:
# array(['Auckland', 'New York', 'Dallas', 'San Franisco', 'NewPort'],
#       dtype=object)

# %%
['New York', 'Dallas', 'NewPort']

# %%
d1=HouseHoldmasterdetail[(HouseHoldmasterdetail["Cities"]=="New York") | (HouseHoldmasterdetail["Cities"]=="Dallas") | (HouseHoldmasterdetail["Cities"]=="NewPort")]

# %%
d1
# Out:
#      HH ID    Cities  Blocks
# 1     5076  New York      19
# 2     5123  New York      23
# 3     5142    Dallas       4
# 4     5143    Dallas      23
# 6     5158    Dallas      13
# ..     ...       ...     ...
# 160   9835  New York       3
# 161   9844    Dallas      23
# 166   9950    Dallas      13
# 167   9952   NewPort      13
# 168   9957  New York       2
#
# [133 rows x 3 columns]

# %%
d1["Cities"].unique()
# Out:
# array(['New York', 'Dallas', 'NewPort'], dtype=object)

# %%
['New York', 'Dallas', 'NewPort']

# %%
d2=HouseHoldmasterdetail[HouseHoldmasterdetail["Cities"].isin(['New York', 'Dallas', 'NewPort'])]

# %%
d2["Cities"].unique()
# Out:
# array(['New York', 'Dallas', 'NewPort'], dtype=object)

# %%
HouseHoldmasterdetail
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 1     5076      New York      19
# 2     5123      New York      23
# 3     5142        Dallas       4
# 4     5143        Dallas      23
# ..     ...           ...     ...
# 164   9881  San Franisco      13
# 165   9898      Auckland      13
# 166   9950        Dallas      13
# 167   9952       NewPort      13
# 168   9957      New York       2
#
# [169 rows x 3 columns]

# %%
d2
# Out:
#      HH ID    Cities  Blocks
# 1     5076  New York      19
# 2     5123  New York      23
# 3     5142    Dallas       4
# 4     5143    Dallas      23
# 6     5158    Dallas      13
# ..     ...       ...     ...
# 160   9835  New York       3
# 161   9844    Dallas      23
# 166   9950    Dallas      13
# 167   9952   NewPort      13
# 168   9957  New York       2
#
# [133 rows x 3 columns]

# %%
HouseHoldmasterdetail.drop(d2.index)
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 5     5153      Auckland      13
# 7     5192  San Franisco      23
# 8     5198      Auckland      13
# 10    5232      Auckland      20
# 13    5436      Auckland      23
# 14    5458      Auckland      20
# 18    5532      Auckland      13
# 19    5546      Auckland      12
# 32    5927  San Franisco      19
# 47    6377  San Franisco       2
# 49    6447  San Franisco      12
# 53    6520      Auckland      12
# 57    6688  San Franisco      18
# 63    6850      Auckland      21
# 67    6961  San Franisco       8
# 70    7004      Auckland      23
# 79    7334      Auckland      21
# 86    7467  San Franisco      12
# 92    7811  San Franisco      15
# 97    7879      Auckland      18
# 104   8050      Auckland       3
# 106   8117  San Franisco       5
# 108   8200      Auckland      12
# 110   8247  San Franisco       9
# 111   8279  San Franisco       9
# 128   9027  San Franisco      20
# 135   9188  San Franisco       9
# 136   9230      Auckland      20
# 138   9302  San Franisco      13
# 139   9314  San Franisco       2
# 142   9396      Auckland       5
# 162   9857      Auckland       2
# 163   9859  San Franisco      12
# 164   9881  San Franisco      13
# 165   9898      Auckland      13

# %%
HouseHoldmasterdetail.shape
# Out:
# (169, 3)

# %%
HouseHoldmasterdetail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HH ID   169 non-null    int64
#  1   Cities  169 non-null    object
#  2   Blocks  169 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 4.1+ KB

# %%
HouseHoldmasterdetail.nunique()
# Out:
# HH ID     169
# Cities      5
# Blocks     15
# dtype: int64

# %%
HouseHoldmasterdetail
# Out:
#      HH ID        Cities  Blocks
# 0     5070      Auckland       2
# 1     5076      New York      19
# 2     5123      New York      23
# 3     5142        Dallas       4
# 4     5143        Dallas      23
# ..     ...           ...     ...
# 164   9881  San Franisco      13
# 165   9898      Auckland      13
# 166   9950        Dallas      13
# 167   9952       NewPort      13
# 168   9957      New York       2
#
# [169 rows x 3 columns]

# %%
a=HouseHoldmasterdetail["Cities"].value_counts()
a
# Out:
# New York        68
# Dallas          48
# Auckland        19
# San Franisco    17
# NewPort         17
# Name: Cities, dtype: int64

# %%
print(a)
# Out:
# New York        68
# Dallas          48
# Auckland        19
# San Franisco    17
# NewPort         17
# Name: Cities, dtype: int64

# %%
# Plot a bar chart of the value counts
plt.bar(a.index, a.values)

# Add labels and title to the chart
plt.xlabel('Cities')
plt.ylabel('Count')
plt.title('Value Counts for Cities')

# Show the chart
plt.show()

# %%
b=HouseHoldmasterdetail["Blocks"].value_counts()
b
# Out:
# 13    32
# 2     24
# 4     21
# 12    21
# 23    14
# 9     13
# 20    11
# 3      8
# 19     6
# 18     6
# 5      6
# 21     3
# 8      2
# 16     1
# 15     1
# Name: Blocks, dtype: int64

# %%
# Plot a bar chart of the value counts
plt.bar(b.index, b.values)

# Add labels and title to the chart
plt.xlabel('Blocks')
plt.ylabel('Count')
plt.title('Value Counts for Blocks')

# Show the chart
plt.show()

# %%
HouseHoldmasterdetail.isnull().sum()
#No missing value
# Out:
# HH ID     0
# Cities    0
# Blocks    0
# dtype: int64

# %%
HouseHoldmasterdetail.nunique()
# Out:
# HH ID     169
# Cities      5
# Blocks     15
# dtype: int64

# %% [markdown]
# ### HouseholIndividualDetails

# %%
HouseholIndividualDetails
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education
# 0    6283              4  4844.772198            50   M       SSC
# 1    6283              1  6637.126847            42   F       SSC
# 2    6283              5  9989.732835            17   M       SSC
# 3    6658              2  9875.840557            58   M  Graduate
# 4    6658              3  9432.010587            49   F       SSC
# ..    ...            ...          ...           ...  ..       ...
# 520  5143              3  9608.890364            53   F       HSC
# 521  5143              4  7195.189063            36   M       HSC
# 522  5143              5  9218.902004            32   M        PG
# 523  5153              2  7346.853146            52   F       SSC
# 524  5153              3  8639.334048             4   M       HSC
#
# [525 rows x 6 columns]

# %%
HouseholIndividualDetails.describe()
# Out:
#                 HH  INDIVIDUAL_ID       WEIGHT  Age_in_years
# count   525.000000     525.000000   525.000000    525.000000
# mean   7478.087619       3.005714  5035.849263     39.091429
# std    1481.409890       1.414877  2985.155222     17.905478
# min    5070.000000       1.000000     6.907993      3.000000
# 25%    6169.000000       2.000000  2334.532515     24.000000
# 50%    7375.000000       3.000000  5041.881930     41.000000
# 75%    8806.000000       4.000000  7623.115878     52.000000
# max    9957.000000       5.000000  9989.732835     90.000000

# %%
HouseholIndividualDetails.nunique()
# Out:
# HH               169
# INDIVIDUAL_ID      5
# WEIGHT           525
# Age_in_years      77
# Sex                2
# Education          4
# dtype: int64

# %%
HouseholIndividualDetails.isnull().sum()
# Out:
# HH               0
# INDIVIDUAL_ID    0
# WEIGHT           0
# Age_in_years     0
# Sex              0
# Education        0
# dtype: int64

# %%
bb=HouseholIndividualDetails["Sex"].value_counts()
bb
# Out:
# M    282
# F    243
# Name: Sex, dtype: int64

# %%
# Create a pie chart of the value counts
plt.pie(bb.values, labels=bb.index, autopct='%1.2f%%')

# Add title to the chart
plt.title('Sex')

# Show the chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6748\3963592695.py in <module>
#       1 # Create a pie chart of the value counts
# ----> 2 plt.pie(bb.values, labels=bb.index, autopct='%1.2f%%')
#       3
#       4 # Add title to the chart
#       5 plt.title('Sex')
#
# NameError: name 'bb' is not defined

# %%
HouseholIndividualDetails["Education"]
# Out:
# 0           SSC
# 1           SSC
# 2           SSC
# 3      Graduate
# 4           SSC
#          ...
# 520         HSC
# 521         HSC
# 522          PG
# 523         SSC
# 524         HSC
# Name: Education, Length: 525, dtype: object

# %%
c=HouseholIndividualDetails["Education"].value_counts()
c
# Out:
# SSC         243
# HSC         237
# Graduate     24
# PG           21
# Name: Education, dtype: int64

# %%
# Create a pie chart of the value counts
plt.pie(c.values, labels=c.index, autopct='%1.1f%%')

# Add title to the chart
plt.title('Education')

# Show the chart
plt.show()

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1000\391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
# Create a histogram of age
plt.hist(HouseholIndividualDetails['Age_in_years'], bins=10)

# Add labels and title to the chart
plt.xlabel('Age_in_years')
plt.ylabel('Count')
plt.title('Age Distribution')

# Show the chart
plt.show()

# %%
# Group the data by education and sex
data = HouseholIndividualDetails.groupby(['Education', 'Sex']).size().unstack()

# Create a stacked bar chart
data.plot(kind='bar', stacked=True)

# Add labels and title to the chart
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Education Level and Sex Distribution')

# Show the chart
plt.show()

# %%
data
# Out:
# Sex          F    M
# Education
# Graduate    10   14
# HSC        127  110
# PG           7   14
# SSC         99  144

# %% [markdown]
# ### Viewership data

# %%
Viewership_data_day1
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-01  6283              4                   66      CH3
# 1   2022-12-01  6283              1                   61      CH5
# 2   2022-12-01  6283              4                    1      CH1
# 3   2022-12-01  6283              5                   97      Ch2
# 4   2022-12-01  6658              2                   38      Ch2
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-01  5153              2                   84      CH5
# 797 2022-12-01  5153              2                   35      CH5
# 798 2022-12-01  5153              2                   95      CH5
# 799 2022-12-01  5153              2                   27      Ch2
# 800 2022-12-01  5153              3                   86      CH4
#
# [801 rows x 5 columns]

# %%
Viewership_data_day1.describe()
# Out:
#                 HH  INDIVIDUAL_ID  Duration in minutes
# count   801.000000     801.000000           801.000000
# mean   7545.253433       3.009988            50.991261
# std    1492.663860       1.399071            28.745455
# min    5070.000000       1.000000             1.000000
# 25%    6216.000000       2.000000            26.000000
# 50%    7463.000000       3.000000            52.000000
# 75%    8936.000000       4.000000            76.000000
# max    9957.000000       5.000000           100.000000

# %%
Viewership_data_day1.nunique()
# Out:
# Date                     1
# HH                     169
# INDIVIDUAL_ID            5
# Duration in minutes    100
# Channels                 5
# dtype: int64

# %%
Viewership_data_day1.isnull().sum()
# Out:
# Date                   0
# HH                     0
# INDIVIDUAL_ID          0
# Duration in minutes    0
# Channels               0
# dtype: int64

# %%
Viewership_data_day2
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-02  6283              4                    7      CH4
# 1   2022-12-02  6283              1                   97      CH1
# 2   2022-12-02  6283              4                   99      CH1
# 3   2022-12-02  6283              5                   69      Ch2
# 4   2022-12-02  6658              2                   18      CH1
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-02  5153              2                   86      CH4
# 797 2022-12-02  5153              2                   75      CH1
# 798 2022-12-02  5153              2                   53      CH5
# 799 2022-12-02  5153              2                   87      Ch2
# 800 2022-12-02  5153              3                   40      CH4
#
# [801 rows x 5 columns]

# %%
Viewership_data_day2.describe()
# Out:
#                 HH  INDIVIDUAL_ID  Duration in minutes
# count   801.000000     801.000000           801.000000
# mean   7545.253433       3.009988            51.141074
# std    1492.663860       1.399071            29.120505
# min    5070.000000       1.000000             1.000000
# 25%    6216.000000       2.000000            26.000000
# 50%    7463.000000       3.000000            49.000000
# 75%    8936.000000       4.000000            77.000000
# max    9957.000000       5.000000           100.000000

# %%
Viewership_data_day2.nunique()
# Out:
# Date                     1
# HH                     169
# INDIVIDUAL_ID            5
# Duration in minutes    100
# Channels                 5
# dtype: int64

# %%
Viewership_data_day2.isnull().sum()
# Out:
# Date                   0
# HH                     0
# INDIVIDUAL_ID          0
# Duration in minutes    0
# Channels               0
# dtype: int64

# %%
Viewership_data_day3
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-03  6283              4                   54      CH5
# 1   2022-12-03  6283              1                   95      CH1
# 2   2022-12-03  6283              4                   21      CH3
# 3   2022-12-03  6283              5                   67      Ch2
# 4   2022-12-03  6658              2                   48      CH4
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-03  5153              2                   71      CH5
# 797 2022-12-03  5153              2                   54      CH5
# 798 2022-12-03  5153              2                   34      CH3
# 799 2022-12-03  5153              2                   53      Ch2
# 800 2022-12-03  5153              3                   25      CH3
#
# [801 rows x 5 columns]

# %%
Viewership_data_day3.describe()
# Out:
#                 HH  INDIVIDUAL_ID  Duration in minutes
# count   801.000000     801.000000           801.000000
# mean   7545.253433       3.009988            50.609238
# std    1492.663860       1.399071            29.372919
# min    5070.000000       1.000000             1.000000
# 25%    6216.000000       2.000000            24.000000
# 50%    7463.000000       3.000000            51.000000
# 75%    8936.000000       4.000000            78.000000
# max    9957.000000       5.000000           100.000000

# %%
Viewership_data_day3.nunique()
# Out:
# Date                     1
# HH                     169
# INDIVIDUAL_ID            5
# Duration in minutes    100
# Channels                 5
# dtype: int64

# %%
Viewership_data_day3.isnull().sum()
# Out:
# Date                   0
# HH                     0
# INDIVIDUAL_ID          0
# Duration in minutes    0
# Channels               0
# dtype: int64

# %% [markdown]
# ### Combining Data

# %%
# HouseholIndividualDetails and HouseHoldmasterdetail combine and make full information of # Househol

data= pd.merge(HouseholIndividualDetails,HouseHoldmasterdetail,left_on="HH",right_on="HH ID")

# %%
data
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education  HH ID  \
# 0    6283              4  4844.772198            50   M       SSC   6283
# 1    6283              1  6637.126847            42   F       SSC   6283
# 2    6283              5  9989.732835            17   M       SSC   6283
# 3    6658              2  9875.840557            58   M  Graduate   6658
# 4    6658              3  9432.010587            49   F       SSC   6658
# ..    ...            ...          ...           ...  ..       ...    ...
# 520  5143              3  9608.890364            53   F       HSC   5143
# 521  5143              4  7195.189063            36   M       HSC   5143
# 522  5143              5  9218.902004            32   M        PG   5143
# 523  5153              2  7346.853146            52   F       SSC   5153
# 524  5153              3  8639.334048             4   M       HSC   5153
#
#        Cities  Blocks
# 0      Dallas       4
# 1      Dallas       4
# 2      Dallas       4
# 3      Dallas       4
# 4      Dallas       4
# ..        ...     ...
# 520    Dallas      23
# 521    Dallas      23
# 522    Dallas      23
# 523  Auckland      13
# 524  Auckland      13
#
# [525 rows x 9 columns]

# %%
# dataframe informations
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 525 entries, 0 to 524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HH             525 non-null    int64
#  1   INDIVIDUAL_ID  525 non-null    int64
#  2   WEIGHT         525 non-null    float64
#  3   Age_in_years   525 non-null    int64
#  4   Sex            525 non-null    object
#  5   Education      525 non-null    object
#  6   HH ID          525 non-null    int64
#  7   Cities         525 non-null    object
#  8   Blocks         525 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 41.0+ KB

# %%
data.describe()
# Out:
#                 HH  INDIVIDUAL_ID       WEIGHT  Age_in_years        HH ID  \
# count   525.000000     525.000000   525.000000    525.000000   525.000000
# mean   7478.087619       3.005714  5035.849263     39.091429  7478.087619
# std    1481.409890       1.414877  2985.155222     17.905478  1481.409890
# min    5070.000000       1.000000     6.907993      3.000000  5070.000000
# 25%    6169.000000       2.000000  2334.532515     24.000000  6169.000000
# 50%    7375.000000       3.000000  5041.881930     41.000000  7375.000000
# 75%    8806.000000       4.000000  7623.115878     52.000000  8806.000000
# max    9957.000000       5.000000  9989.732835     90.000000  9957.000000
#
#            Blocks
# count  525.000000
# mean    10.986667
# std      6.846310
# min      2.000000
# 25%      4.000000
# 50%     12.000000
# 75%     15.000000
# max     23.000000

# %%
data.nunique()
# Out:
# HH               169
# INDIVIDUAL_ID      5
# WEIGHT           525
# Age_in_years      77
# Sex                2
# Education          4
# HH ID            169
# Cities             5
# Blocks            15
# dtype: int64

# %%
data.isnull().sum()
# Out:
# HH               0
# INDIVIDUAL_ID    0
# WEIGHT           0
# Age_in_years     0
# Sex              0
# Education        0
# HH ID            0
# Cities           0
# Blocks           0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### We taken sample from 525 individual but in Viewership_data there are 801 records present.
# ### This indicates that there are some individual who saw more than one channel

# %% [markdown]
# ### So now we make one record for one individual

# %% [markdown]
# ### Viewership_data

# %%
# create dummy variables for categorical variables
one_hot_encoded_data1 = pd.get_dummies(Viewership_data_day1, columns=['Channels'])
one_hot_encoded_data1
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes  Channels_CH1  \
# 0   2022-12-01  6283              4                   66             0
# 1   2022-12-01  6283              1                   61             0
# 2   2022-12-01  6283              4                    1             1
# 3   2022-12-01  6283              5                   97             0
# 4   2022-12-01  6658              2                   38             0
# ..         ...   ...            ...                  ...           ...
# 796 2022-12-01  5153              2                   84             0
# 797 2022-12-01  5153              2                   35             0
# 798 2022-12-01  5153              2                   95             0
# 799 2022-12-01  5153              2                   27             0
# 800 2022-12-01  5153              3                   86             0
#
#      Channels_CH3  Channels_CH4  Channels_CH5  Channels_Ch2
# 0               1             0             0             0
# 1               0             0             1             0
# 2               0             0             0             0
# 3               0             0             0             1
# 4               0             0             0             1
# ..            ...           ...           ...           ...
# 796             0             0             1             0
# 797             0             0             1             0
# 798             0             0             1             0
# 799             0             0             0             1
# 800             0             1             0             0
#
# [801 rows x 9 columns]

# %%
# Group the data by 'HH', 'INDIVIDUAL_ID' and 'Channels', and aggregate the 'Duration in minutes' column
grouped11 = one_hot_encoded_data1.groupby(['HH', 'INDIVIDUAL_ID','Channels_CH1','Channels_CH3',
                'Channels_CH4', 'Channels_CH5', 'Channels_Ch2']).agg({'Duration in minutes': 'sum', 'Channels_CH1':'sum',
       'Channels_CH3':'sum', 'Channels_CH4':'sum', 'Channels_CH5':'sum', 'Channels_Ch2':'sum'})

# Rename the aggregated columns
grouped11 = grouped11.rename(columns={'Duration in minutes': 'Total Duration','Channels_CH1':"CH_1",
       'Channels_CH3':"CH_3", 'Channels_CH4':"CH_4", 'Channels_CH5':"CH_5", 'Channels_Ch2':"CH_2"})

# # Reset the index to turn the grouped columns into regular columns
grouped11 = grouped11.reset_index()
grouped11
# Out:
#        HH  INDIVIDUAL_ID  Channels_CH1  Channels_CH3  Channels_CH4  \
# 0    5070              1             0             1             0
# 1    5070              3             0             0             0
# 2    5070              3             1             0             0
# 3    5070              4             0             1             0
# 4    5076              3             0             0             1
# ..    ...            ...           ...           ...           ...
# 728  9957              2             0             0             1
# 729  9957              3             0             0             0
# 730  9957              3             0             0             1
# 731  9957              3             1             0             0
# 732  9957              5             0             1             0
#
#      Channels_CH5  Channels_Ch2  Total Duration  CH_1  CH_3  CH_4  CH_5  CH_2
# 0               0             0              57     0     1     0     0     0
# 1               1             0              48     0     0     0     1     0
# 2               0             0              31     1     0     0     0     0
# 3               0             0              54     0     1     0     0     0
# 4               0             0              89     0     0     1     0     0
# ..            ...           ...             ...   ...   ...   ...   ...   ...
# 728             0             0              53     0     0     1     0     0
# 729             0             1              29     0     0     0     0     1
# 730             0             0              37     0     0     1     0     0
# 731             0             0              90     1     0     0     0     0
# 732             0             0              35     0     1     0     0     0
#
# [733 rows x 13 columns]

# %%
# Group the data by 'HH', 'INDIVIDUAL_ID' and aggregate the 'Duration in minutes' column
grouped1 = grouped11.groupby(['HH', 'INDIVIDUAL_ID']).agg({'Total Duration': 'sum', 'CH_1':'sum',
       'CH_3':'sum', 'CH_4':'sum', 'CH_5':'sum', 'CH_2':'sum'})

# Rename the aggregated columns 
grouped1 = grouped1.rename(columns={'Total Duration': 'Duration in minutes',"CH_1":'CH1',
       "CH_3":'CH3', "CH_4":'CH4', "CH_5":'CH5', "CH_2":'CH2'})

# Reset the index to turn the grouped columns into regular columns
grouped1 = grouped1.reset_index()
grouped1
# Out:
#        HH  INDIVIDUAL_ID  Duration in minutes  CH1  CH3  CH4  CH5  CH2
# 0    5070              1                   57    0    1    0    0    0
# 1    5070              3                   79    1    0    0    1    0
# 2    5070              4                   54    0    1    0    0    0
# 3    5076              3                   89    0    0    1    0    0
# 4    5076              4                    6    0    0    0    1    0
# ..    ...            ...                  ...  ...  ...  ...  ...  ...
# 520  9952              5                  134    2    0    0    0    1
# 521  9957              1                   66    0    0    0    1    0
# 522  9957              2                   53    0    0    1    0    0
# 523  9957              3                  156    1    0    1    0    1
# 524  9957              5                   35    0    1    0    0    0
#
# [525 rows x 8 columns]

# %%
df1=pd.merge(data,grouped1,on=["HH","INDIVIDUAL_ID"])

# %%
df1
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education  HH ID  \
# 0    6283              4  4844.772198            50   M       SSC   6283
# 1    6283              1  6637.126847            42   F       SSC   6283
# 2    6283              5  9989.732835            17   M       SSC   6283
# 3    6658              2  9875.840557            58   M  Graduate   6658
# 4    6658              3  9432.010587            49   F       SSC   6658
# ..    ...            ...          ...           ...  ..       ...    ...
# 520  5143              3  9608.890364            53   F       HSC   5143
# 521  5143              4  7195.189063            36   M       HSC   5143
# 522  5143              5  9218.902004            32   M        PG   5143
# 523  5153              2  7346.853146            52   F       SSC   5153
# 524  5153              3  8639.334048             4   M       HSC   5153
#
#        Cities  Blocks  Duration in minutes  CH1  CH3  CH4  CH5  CH2
# 0      Dallas       4                   67    1    1    0    0    0
# 1      Dallas       4                   61    0    0    0    1    0
# 2      Dallas       4                   97    0    0    0    0    1
# 3      Dallas       4                  132    0    0    0    0    2
# 4      Dallas       4                   65    0    0    0    1    0
# ..        ...     ...                  ...  ...  ...  ...  ...  ...
# 520    Dallas      23                   62    1    0    0    0    0
# 521    Dallas      23                   43    1    0    0    0    0
# 522    Dallas      23                   78    0    1    0    0    0
# 523  Auckland      13                  241    0    0    0    3    1
# 524  Auckland      13                   86    0    0    1    0    0
#
# [525 rows x 15 columns]

# %%
df1['CH1'].value_counts()
# Out:
# 0    370
# 1    141
# 2     12
# 3      2
# Name: CH1, dtype: int64

# %%
df1['CH2'].value_counts()
# Out:
# 0    400
# 1    111
# 2     12
# 3      2
# Name: CH2, dtype: int64

# %%
df1['CH3'].value_counts()
# Out:
# 0    368
# 1    152
# 2      5
# Name: CH3, dtype: int64

# %%
df1['CH4'].value_counts()
# Out:
# 0    377
# 1    137
# 2     10
# 3      1
# Name: CH4, dtype: int64

# %%
df1['CH5'].value_counts()
# Out:
# 0    377
# 1    130
# 2     17
# 3      1
# Name: CH5, dtype: int64

# %%
df1.describe()
# Out:
#                 HH  INDIVIDUAL_ID       WEIGHT  Age_in_years        HH ID  \
# count   525.000000     525.000000   525.000000    525.000000   525.000000
# mean   7478.087619       3.005714  5035.849263     39.091429  7478.087619
# std    1481.409890       1.414877  2985.155222     17.905478  1481.409890
# min    5070.000000       1.000000     6.907993      3.000000  5070.000000
# 25%    6169.000000       2.000000  2334.532515     24.000000  6169.000000
# 50%    7375.000000       3.000000  5041.881930     41.000000  7375.000000
# 75%    8806.000000       4.000000  7623.115878     52.000000  8806.000000
# max    9957.000000       5.000000  9989.732835     90.000000  9957.000000
#
#            Blocks  Duration in minutes         CH1         CH3         CH4  \
# count  525.000000           525.000000  525.000000  525.000000  525.000000
# mean    10.986667            77.798095    0.325714    0.308571    0.304762
# std      6.846310            51.803663    0.537351    0.482541    0.511766
# min      2.000000             1.000000    0.000000    0.000000    0.000000
# 25%      4.000000            38.000000    0.000000    0.000000    0.000000
# 50%     12.000000            70.000000    0.000000    0.000000    0.000000
# 75%     15.000000           101.000000    1.000000    1.000000    1.000000
# max     23.000000           273.000000    3.000000    2.000000    3.000000
#
#               CH5         CH2
# count  525.000000  525.000000
# mean     0.318095    0.268571
# std      0.541904    0.515284
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    0.000000
# max      3.000000    3.000000

# %%
df1.nunique()
# Out:
# HH                     169
# INDIVIDUAL_ID            5
# WEIGHT                 525
# Age_in_years            77
# Sex                      2
# Education                4
# HH ID                  169
# Cities                   5
# Blocks                  15
# Duration in minutes    175
# CH1                      4
# CH3                      3
# CH4                      4
# CH5                      4
# CH2                      4
# dtype: int64

# %%
dfg=df1.groupby(['Sex'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Sex  Duration in minutes
# 0   F            76.942387
# 1   M            78.535461

# %%
dfg=df1.groupby(['Education'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Education  Duration in minutes
# 0  Graduate            68.000000
# 1       HSC            79.894515
# 2        PG            89.000000
# 3       SSC            75.753086

# %%
dfg=df1.groupby(['Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#          Cities  Duration in minutes
# 0      Auckland            73.921875
# 1        Dallas            75.866197
# 2      New York            81.427885
# 3       NewPort            68.508772
# 4  San Franisco            83.296296

# %%
dfg=df1.groupby(['Blocks'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#     Blocks  Duration in minutes
# 0        2            79.129870
# 1        3            91.615385
# 2        4            79.952381
# 3        5            80.400000
# 4        8            94.200000
# 5        9            75.789474
# 6       12            78.338235
# 7       13            77.643564
# 8       15            85.000000
# 9       16            74.500000
# 10      18            85.684211
# 11      19            62.250000
# 12      20            70.205128
# 13      21            70.875000
# 14      23            72.454545

# %%
dfg=Viewership_data_day1.groupby(['Channels'])['Duration in minutes'].mean().reset_index
dfg
# Out:
# <bound method Series.reset_index of Channels
# CH1    48.894737
# CH3    51.740741
# CH4    52.406250
# CH5    50.796407
# Ch2    51.297872
# Name: Duration in minutes, dtype: float64>

# %%
# Group the data by sex, education, and city and calculate the average duration in minutes
dfg=df1.groupby(['Sex', 'Education', 'Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#    Sex Education        Cities  Duration in minutes
# 0    F  Graduate      Auckland            51.000000
# 1    F  Graduate        Dallas            34.000000
# 2    F  Graduate      New York            94.600000
# 3    F  Graduate       NewPort            31.000000
# 4    F  Graduate  San Franisco            17.000000
# 5    F       HSC      Auckland            68.200000
# 6    F       HSC        Dallas            64.064516
# 7    F       HSC      New York            81.821429
# 8    F       HSC       NewPort            63.823529
# 9    F       HSC  San Franisco            88.153846
# 10   F        PG      Auckland           128.000000
# 11   F        PG        Dallas            89.500000
# 12   F        PG      New York           126.000000
# 13   F       SSC      Auckland           100.428571
# 14   F       SSC        Dallas            81.652174
# 15   F       SSC      New York            70.763158
# 16   F       SSC       NewPort            77.846154
# 17   F       SSC  San Franisco            76.000000
# 18   M  Graduate      Auckland            66.750000
# 19   M  Graduate        Dallas           105.000000
# 20   M  Graduate      New York            41.333333
# 21   M  Graduate  San Franisco            67.250000
# 22   M       HSC      Auckland            62.142857
# 23   M       HSC        Dallas            84.846154
# 24   M       HSC      New York            93.978723
# 25   M       HSC       NewPort            67.750000
# 26   M       HSC  San Franisco            94.600000
# 27   M        PG        Dallas            59.833333
# 28   M        PG      New York            88.000000
# 29   M        PG       NewPort           106.666667
# 30   M        PG  San Franisco           100.000000
# 31   M       SSC      Auckland            67.157895
# 32   M       SSC        Dallas            75.770833
# 33   M       SSC      New York            76.377358
# 34   M       SSC       NewPort            61.000000
# 35   M       SSC  San Franisco            79.000000

# %%
# Create a bar plot using seaborn
sns.barplot(x='Sex', y='Duration in minutes', hue='Education', data=dfg)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Duration in minutes'>

# %%
# create dummy variables for categorical variables
one_hot_encoded_data2 = pd.get_dummies(Viewership_data_day2, columns=['Channels'])
one_hot_encoded_data2.head()

# Group the data by 'HH', 'INDIVIDUAL_ID' and 'Channels', and aggregate the 'Duration in minutes' column
grouped22 = one_hot_encoded_data2.groupby(['HH', 'INDIVIDUAL_ID','Channels_CH1','Channels_CH3',
                'Channels_CH4', 'Channels_CH5', 'Channels_Ch2']).agg({'Duration in minutes': 'sum', 'Channels_CH1':'sum',
       'Channels_CH3':'sum', 'Channels_CH4':'sum', 'Channels_CH5':'sum', 'Channels_Ch2':'sum'})

# Rename the aggregated columns
grouped22 = grouped22.rename(columns={'Duration in minutes': 'Total Duration','Channels_CH1':"CH_1",
       'Channels_CH3':"CH_3", 'Channels_CH4':"CH_4", 'Channels_CH5':"CH_5", 'Channels_Ch2':"CH_2"})

# Reset the index to turn the grouped columns into regular columns
grouped22 = grouped22.reset_index()
grouped22

# Group the data by 'HH', 'INDIVIDUAL_ID' and aggregate the 'Duration in minutes' column
grouped2 = grouped22.groupby(['HH', 'INDIVIDUAL_ID']).agg({'Total Duration': 'sum', 'CH_1':'sum',
       'CH_3':'sum', 'CH_4':'sum', 'CH_5':'sum', 'CH_2':'sum'})

# Rename the aggregated columns 
grouped2 = grouped2.rename(columns={'Total Duration': 'Duration in minutes',"CH_1":'CH1',
       "CH_3":'CH3', "CH_4":'CH4', "CH_5":'CH5', "CH_2":'CH2'})

# Reset the index to turn the grouped columns into regular columns
grouped2 = grouped2.reset_index()
grouped2

df2=pd.merge(data,grouped2,on=["HH","INDIVIDUAL_ID"])
df2
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education  HH ID  \
# 0    6283              4  4844.772198            50   M       SSC   6283
# 1    6283              1  6637.126847            42   F       SSC   6283
# 2    6283              5  9989.732835            17   M       SSC   6283
# 3    6658              2  9875.840557            58   M  Graduate   6658
# 4    6658              3  9432.010587            49   F       SSC   6658
# ..    ...            ...          ...           ...  ..       ...    ...
# 520  5143              3  9608.890364            53   F       HSC   5143
# 521  5143              4  7195.189063            36   M       HSC   5143
# 522  5143              5  9218.902004            32   M        PG   5143
# 523  5153              2  7346.853146            52   F       SSC   5153
# 524  5153              3  8639.334048             4   M       HSC   5153
#
#        Cities  Blocks  Duration in minutes  CH1  CH3  CH4  CH5  CH2
# 0      Dallas       4                  106    1    0    1    0    0
# 1      Dallas       4                   97    1    0    0    0    0
# 2      Dallas       4                   69    0    0    0    0    1
# 3      Dallas       4                   68    1    0    1    0    0
# 4      Dallas       4                   68    0    0    1    0    0
# ..        ...     ...                  ...  ...  ...  ...  ...  ...
# 520    Dallas      23                   83    0    0    1    0    0
# 521    Dallas      23                   90    0    1    0    0    0
# 522    Dallas      23                   72    1    0    0    0    0
# 523  Auckland      13                  301    1    0    1    1    1
# 524  Auckland      13                   40    0    0    1    0    0
#
# [525 rows x 15 columns]

# %%
df2.describe()
# Out:
#                 HH  INDIVIDUAL_ID       WEIGHT  Age_in_years        HH ID  \
# count   525.000000     525.000000   525.000000    525.000000   525.000000
# mean   7478.087619       3.005714  5035.849263     39.091429  7478.087619
# std    1481.409890       1.414877  2985.155222     17.905478  1481.409890
# min    5070.000000       1.000000     6.907993      3.000000  5070.000000
# 25%    6169.000000       2.000000  2334.532515     24.000000  6169.000000
# 50%    7375.000000       3.000000  5041.881930     41.000000  7375.000000
# 75%    8806.000000       4.000000  7623.115878     52.000000  8806.000000
# max    9957.000000       5.000000  9989.732835     90.000000  9957.000000
#
#            Blocks  Duration in minutes         CH1         CH3         CH4  \
# count  525.000000           525.000000  525.000000  525.000000  525.000000
# mean    10.986667            78.026667    0.310476    0.320000    0.289524
# std      6.846310            52.565692    0.528559    0.498548    0.486443
# min      2.000000             1.000000    0.000000    0.000000    0.000000
# 25%      4.000000            36.000000    0.000000    0.000000    0.000000
# 50%     12.000000            73.000000    0.000000    0.000000    0.000000
# 75%     15.000000           104.000000    1.000000    1.000000    1.000000
# max     23.000000           307.000000    2.000000    2.000000    3.000000
#
#               CH5         CH2
# count  525.000000  525.000000
# mean     0.348571    0.257143
# std      0.554667    0.487018
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    0.000000
# max      3.000000    3.000000

# %%
df2.nunique()
# Out:
# HH                     169
# INDIVIDUAL_ID            5
# WEIGHT                 525
# Age_in_years            77
# Sex                      2
# Education                4
# HH ID                  169
# Cities                   5
# Blocks                  15
# Duration in minutes    179
# CH1                      3
# CH3                      3
# CH4                      4
# CH5                      4
# CH2                      4
# dtype: int64

# %%
dfg=df2.groupby(['Sex'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Sex  Duration in minutes
# 0   F            78.757202
# 1   M            77.397163

# %%
dfg=df2.groupby(['Education'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Education  Duration in minutes
# 0  Graduate            75.583333
# 1       HSC            78.185654
# 2        PG            85.190476
# 3       SSC            77.493827

# %%
dfg=df2.groupby(['Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#          Cities  Duration in minutes
# 0      Auckland            72.046875
# 1        Dallas            76.394366
# 2      New York            78.879808
# 3       NewPort            79.438596
# 4  San Franisco            84.629630

# %%
dfg=df2.groupby(['Blocks'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#     Blocks  Duration in minutes
# 0        2            79.519481
# 1        3            74.615385
# 2        4            77.301587
# 3        5            77.800000
# 4        8            87.000000
# 5        9            71.868421
# 6       12            78.205882
# 7       13            80.712871
# 8       15            82.000000
# 9       16            81.000000
# 10      18            83.789474
# 11      19            99.062500
# 12      20            72.846154
# 13      21            68.625000
# 14      23            72.068182

# %%
dfg=Viewership_data_day2.groupby(['Channels'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Channels  Duration in minutes
# 0      CH1            50.233129
# 1      CH3            49.898810
# 2      CH4            48.434211
# 3      CH5            50.918033
# 4      Ch2            57.133333

# %%
dfg=df2.groupby(['Sex', 'Education', 'Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#    Sex Education        Cities  Duration in minutes
# 0    F  Graduate      Auckland            80.000000
# 1    F  Graduate        Dallas            97.000000
# 2    F  Graduate      New York            64.600000
# 3    F  Graduate       NewPort            95.000000
# 4    F  Graduate  San Franisco            99.000000
# 5    F       HSC      Auckland            55.300000
# 6    F       HSC        Dallas            67.580645
# 7    F       HSC      New York            84.375000
# 8    F       HSC       NewPort            72.941176
# 9    F       HSC  San Franisco            99.923077
# 10   F        PG      Auckland            68.000000
# 11   F        PG        Dallas           113.750000
# 12   F        PG      New York            75.500000
# 13   F       SSC      Auckland            91.928571
# 14   F       SSC        Dallas            91.347826
# 15   F       SSC      New York            67.973684
# 16   F       SSC       NewPort            89.846154
# 17   F       SSC  San Franisco            58.090909
# 18   M  Graduate      Auckland            73.000000
# 19   M  Graduate        Dallas            84.000000
# 20   M  Graduate      New York            65.333333
# 21   M  Graduate  San Franisco            75.000000
# 22   M       HSC      Auckland            53.214286
# 23   M       HSC        Dallas            84.192308
# 24   M       HSC      New York            80.170213
# 25   M       HSC       NewPort            73.000000
# 26   M       HSC  San Franisco            88.800000
# 27   M        PG        Dallas            50.500000
# 28   M        PG      New York            92.500000
# 29   M        PG       NewPort           126.333333
# 30   M        PG  San Franisco            63.000000
# 31   M       SSC      Auckland            79.263158
# 32   M       SSC        Dallas            69.916667
# 33   M       SSC      New York            80.962264
# 34   M       SSC       NewPort            70.800000
# 35   M       SSC  San Franisco            93.111111

# %%
sns.barplot(x='Sex', y='Duration in minutes', hue='Education', data=dfg)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Duration in minutes'>

# %%
# create dummy variables for categorical variables
one_hot_encoded_data3 = pd.get_dummies(Viewership_data_day3, columns=['Channels'])
one_hot_encoded_data3.head()

# Group the data by 'HH', 'INDIVIDUAL_ID' and 'Channels', and aggregate the 'Duration in minutes' column
grouped33 = one_hot_encoded_data3.groupby(['HH', 'INDIVIDUAL_ID','Channels_CH1','Channels_CH3',
                'Channels_CH4', 'Channels_CH5', 'Channels_Ch2']).agg({'Duration in minutes': 'sum', 'Channels_CH1':'sum',
       'Channels_CH3':'sum', 'Channels_CH4':'sum', 'Channels_CH5':'sum', 'Channels_Ch2':'sum'})

# Rename the aggregated columns
grouped33 = grouped33.rename(columns={'Duration in minutes': 'Total Duration','Channels_CH1':"CH_1",
       'Channels_CH3':"CH_3", 'Channels_CH4':"CH_4", 'Channels_CH5':"CH_5", 'Channels_Ch2':"CH_2"})

# Reset the index to turn the grouped columns into regular columns
grouped33 = grouped33.reset_index()
grouped33

# Group the data by 'HH', 'INDIVIDUAL_ID' and aggregate the 'Duration in minutes' column
grouped3 = grouped33.groupby(['HH', 'INDIVIDUAL_ID']).agg({'Total Duration': 'sum', 'CH_1':'sum',
       'CH_3':'sum', 'CH_4':'sum', 'CH_5':'sum', 'CH_2':'sum'})

# Rename the aggregated columns 
grouped3 = grouped3.rename(columns={'Total Duration': 'Duration in minutes',"CH_1":'CH1',
       "CH_3":'CH3', "CH_4":'CH4', "CH_5":'CH5', "CH_2":'CH2'})

# Reset the index to turn the grouped columns into regular columns
grouped3 = grouped3.reset_index()
grouped3

df3=pd.merge(data,grouped3,on=["HH","INDIVIDUAL_ID"])
df3
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education  HH ID  \
# 0    6283              4  4844.772198            50   M       SSC   6283
# 1    6283              1  6637.126847            42   F       SSC   6283
# 2    6283              5  9989.732835            17   M       SSC   6283
# 3    6658              2  9875.840557            58   M  Graduate   6658
# 4    6658              3  9432.010587            49   F       SSC   6658
# ..    ...            ...          ...           ...  ..       ...    ...
# 520  5143              3  9608.890364            53   F       HSC   5143
# 521  5143              4  7195.189063            36   M       HSC   5143
# 522  5143              5  9218.902004            32   M        PG   5143
# 523  5153              2  7346.853146            52   F       SSC   5153
# 524  5153              3  8639.334048             4   M       HSC   5153
#
#        Cities  Blocks  Duration in minutes  CH1  CH3  CH4  CH5  CH2
# 0      Dallas       4                   75    0    1    0    1    0
# 1      Dallas       4                   95    1    0    0    0    0
# 2      Dallas       4                   67    0    0    0    0    1
# 3      Dallas       4                   80    0    0    1    1    0
# 4      Dallas       4                   94    0    0    0    0    1
# ..        ...     ...                  ...  ...  ...  ...  ...  ...
# 520    Dallas      23                   92    0    1    0    0    0
# 521    Dallas      23                   18    0    1    0    0    0
# 522    Dallas      23                    5    0    1    0    0    0
# 523  Auckland      13                  212    0    1    0    2    1
# 524  Auckland      13                   25    0    1    0    0    0
#
# [525 rows x 15 columns]

# %%
df3.describe()
# Out:
#                 HH  INDIVIDUAL_ID       WEIGHT  Age_in_years        HH ID  \
# count   525.000000     525.000000   525.000000    525.000000   525.000000
# mean   7478.087619       3.005714  5035.849263     39.091429  7478.087619
# std    1481.409890       1.414877  2985.155222     17.905478  1481.409890
# min    5070.000000       1.000000     6.907993      3.000000  5070.000000
# 25%    6169.000000       2.000000  2334.532515     24.000000  6169.000000
# 50%    7375.000000       3.000000  5041.881930     41.000000  7375.000000
# 75%    8806.000000       4.000000  7623.115878     52.000000  8806.000000
# max    9957.000000       5.000000  9989.732835     90.000000  9957.000000
#
#            Blocks  Duration in minutes         CH1         CH3         CH4  \
# count  525.000000           525.000000  525.000000  525.000000  525.000000
# mean    10.986667            77.215238    0.308571    0.299048    0.274286
# std      6.846310            53.646402    0.531474    0.509545    0.502860
# min      2.000000             1.000000    0.000000    0.000000    0.000000
# 25%      4.000000            35.000000    0.000000    0.000000    0.000000
# 50%     12.000000            72.000000    0.000000    0.000000    0.000000
# 75%     15.000000            98.000000    1.000000    1.000000    0.000000
# max     23.000000           287.000000    3.000000    3.000000    2.000000
#
#               CH5         CH2
# count  525.000000  525.000000
# mean     0.335238    0.308571
# std      0.547371    0.520590
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      1.000000    1.000000
# max      2.000000    2.000000

# %%
df3.nunique()
# Out:
# HH                     169
# INDIVIDUAL_ID            5
# WEIGHT                 525
# Age_in_years            77
# Sex                      2
# Education                4
# HH ID                  169
# Cities                   5
# Blocks                  15
# Duration in minutes    180
# CH1                      4
# CH3                      4
# CH4                      3
# CH5                      3
# CH2                      3
# dtype: int64

# %%
dfg=df3.groupby(['Sex'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Sex  Duration in minutes
# 0   F            77.189300
# 1   M            77.237589

# %%
dfg=df3.groupby(['Education'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Education  Duration in minutes
# 0  Graduate            69.208333
# 1       HSC            78.746835
# 2        PG            74.571429
# 3       SSC            76.740741

# %%
dfg=df3.groupby(['Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#          Cities  Duration in minutes
# 0      Auckland            69.031250
# 1        Dallas            72.950704
# 2      New York            82.822115
# 3       NewPort            71.035088
# 4  San Franisco            83.055556

# %%
dfg=df3.groupby(['Blocks'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#     Blocks  Duration in minutes
# 0        2            83.233766
# 1        3            79.923077
# 2        4            73.777778
# 3        5            81.533333
# 4        8           102.400000
# 5        9            77.500000
# 6       12            83.338235
# 7       13            71.386139
# 8       15            92.250000
# 9       16           104.500000
# 10      18            78.210526
# 11      19            90.250000
# 12      20            71.461538
# 13      21            60.625000
# 14      23            69.681818

# %%
dfg=Viewership_data_day3.groupby(['Channels'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Channels  Duration in minutes
# 0      CH1            46.870370
# 1      CH3            50.038217
# 2      CH4            52.659722
# 3      CH5            51.829545
# 4      Ch2            51.753086

# %%
dfg=df3.groupby(['Sex', 'Education', 'Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#    Sex Education        Cities  Duration in minutes
# 0    F  Graduate      Auckland            22.000000
# 1    F  Graduate        Dallas            88.000000
# 2    F  Graduate      New York            81.800000
# 3    F  Graduate       NewPort            92.000000
# 4    F  Graduate  San Franisco            23.000000
# 5    F       HSC      Auckland            46.700000
# 6    F       HSC        Dallas            65.032258
# 7    F       HSC      New York            86.196429
# 8    F       HSC       NewPort            68.294118
# 9    F       HSC  San Franisco           105.461538
# 10   F        PG      Auckland           144.000000
# 11   F        PG        Dallas            67.750000
# 12   F        PG      New York            74.500000
# 13   F       SSC      Auckland           102.571429
# 14   F       SSC        Dallas            78.608696
# 15   F       SSC      New York            78.315789
# 16   F       SSC       NewPort            69.461538
# 17   F       SSC  San Franisco            52.000000
# 18   M  Graduate      Auckland            50.750000
# 19   M  Graduate        Dallas           121.666667
# 20   M  Graduate      New York            43.333333
# 21   M  Graduate  San Franisco            76.750000
# 22   M       HSC      Auckland            45.714286
# 23   M       HSC        Dallas            84.923077
# 24   M       HSC      New York            83.744681
# 25   M       HSC       NewPort            82.875000
# 26   M       HSC  San Franisco            91.600000
# 27   M        PG        Dallas            41.500000
# 28   M        PG      New York           109.750000
# 29   M        PG       NewPort            88.000000
# 30   M        PG  San Franisco            50.000000
# 31   M       SSC      Auckland            78.105263
# 32   M       SSC        Dallas            69.875000
# 33   M       SSC      New York            82.283019
# 34   M       SSC       NewPort            64.400000
# 35   M       SSC  San Franisco            87.555556

# %%
sns.barplot(x='Sex', y='Duration in minutes', hue='Education', data=dfg)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Duration in minutes'>

# %%
dd=pd.concat([df1,df2,df3],axis=0)
dd
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education  HH ID  \
# 0    6283              4  4844.772198            50   M       SSC   6283
# 1    6283              1  6637.126847            42   F       SSC   6283
# 2    6283              5  9989.732835            17   M       SSC   6283
# 3    6658              2  9875.840557            58   M  Graduate   6658
# 4    6658              3  9432.010587            49   F       SSC   6658
# ..    ...            ...          ...           ...  ..       ...    ...
# 520  5143              3  9608.890364            53   F       HSC   5143
# 521  5143              4  7195.189063            36   M       HSC   5143
# 522  5143              5  9218.902004            32   M        PG   5143
# 523  5153              2  7346.853146            52   F       SSC   5153
# 524  5153              3  8639.334048             4   M       HSC   5153
#
#        Cities  Blocks  Duration in minutes  CH1  CH3  CH4  CH5  CH2
# 0      Dallas       4                   67    1    1    0    0    0
# 1      Dallas       4                   61    0    0    0    1    0
# 2      Dallas       4                   97    0    0    0    0    1
# 3      Dallas       4                  132    0    0    0    0    2
# 4      Dallas       4                   65    0    0    0    1    0
# ..        ...     ...                  ...  ...  ...  ...  ...  ...
# 520    Dallas      23                   92    0    1    0    0    0
# 521    Dallas      23                   18    0    1    0    0    0
# 522    Dallas      23                    5    0    1    0    0    0
# 523  Auckland      13                  212    0    1    0    2    1
# 524  Auckland      13                   25    0    1    0    0    0
#
# [1575 rows x 15 columns]

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1575 entries, 0 to 524
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   HH                   1575 non-null   int64
#  1   INDIVIDUAL_ID        1575 non-null   int64
#  2   WEIGHT               1575 non-null   float64
#  3   Age_in_years         1575 non-null   int64
#  4   Sex                  1575 non-null   object
#  5   Education            1575 non-null   object
#  6   HH ID                1575 non-null   int64
#  7   Cities               1575 non-null   object
#  8   Blocks               1575 non-null   int64
#  9   Duration in minutes  1575 non-null   int64
#  10  CH1                  1575 non-null   uint8
#  11  CH3                  1575 non-null   uint8
#  12  CH4                  1575 non-null   uint8
#  13  CH5                  1575 non-null   uint8
#  14  CH2                  1575 non-null   uint8
# dtypes: float64(1), int64(6), object(3), uint8(5)
# memory usage: 143.0+ KB

# %%
dd.drop(["HH ID"],axis=1,inplace=True)

# %%
dd.isnull().sum()
# Out:
# HH                     0
# INDIVIDUAL_ID          0
# WEIGHT                 0
# Age_in_years           0
# Sex                    0
# Education              0
# Cities                 0
# Blocks                 0
# Duration in minutes    0
# CH1                    0
# CH3                    0
# CH4                    0
# CH5                    0
# CH2                    0
# dtype: int64

# %%
dd.describe()
# Out:
#                 HH  INDIVIDUAL_ID       WEIGHT  Age_in_years       Blocks  \
# count  1575.000000    1575.000000  1575.000000   1575.000000  1575.000000
# mean   7478.087619       3.005714  5035.849263     39.091429    10.986667
# std    1480.468416       1.413977  2983.258078     17.894098     6.841959
# min    5070.000000       1.000000     6.907993      3.000000     2.000000
# 25%    6169.000000       2.000000  2334.532515     24.000000     4.000000
# 50%    7375.000000       3.000000  5041.881930     41.000000    12.000000
# 75%    8806.000000       4.000000  7623.115878     52.000000    15.000000
# max    9957.000000       5.000000  9989.732835     90.000000    23.000000
#
#        Duration in minutes          CH1          CH3          CH4  \
# count          1575.000000  1575.000000  1575.000000  1575.000000
# mean             77.680000     0.314921     0.309206     0.289524
# std              52.644976     0.532191     0.496760     0.500303
# min               1.000000     0.000000     0.000000     0.000000
# 25%              37.000000     0.000000     0.000000     0.000000
# 50%              72.000000     0.000000     0.000000     0.000000
# 75%             100.000000     1.000000     1.000000     1.000000
# max             307.000000     3.000000     3.000000     3.000000
#
#                CH5          CH2
# count  1575.000000  1575.000000
# mean      0.333968     0.278095
# std       0.547800     0.508001
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       1.000000     1.000000
# max       3.000000     3.000000

# %%
dd.nunique()
# Out:
# HH                     169
# INDIVIDUAL_ID            5
# WEIGHT                 525
# Age_in_years            77
# Sex                      2
# Education                4
# Cities                   5
# Blocks                  15
# Duration in minutes    227
# CH1                      4
# CH3                      4
# CH4                      4
# CH5                      4
# CH2                      4
# dtype: int64

# %%
dd.duplicated().sum()
# Out:
# 1

# %%
dd.drop_duplicates(inplace=True)

# %%
dd.duplicated().sum()
# Out:
# 0

# %%
dfg=dd.groupby(['Sex'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Sex  Duration in minutes
# 0   F            77.712912
# 1   M            77.723404

# %%
dfg=dd.groupby(['Education'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#   Education  Duration in minutes
# 0  Graduate            70.930556
# 1       HSC            79.029577
# 2        PG            82.920635
# 3       SSC            76.662551

# %%
dfg=dd.groupby(['Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#          Cities  Duration in minutes
# 0      Auckland            71.666667
# 1        Dallas            75.070423
# 2      New York            81.146067
# 3       NewPort            72.994152
# 4  San Franisco            83.660494

# %%
dfg=dd.groupby(['Blocks'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#     Blocks  Duration in minutes
# 0        2            80.627706
# 1        3            82.051282
# 2        4            77.010582
# 3        5            79.911111
# 4        8            94.533333
# 5        9            75.052632
# 6       12            79.960784
# 7       13            76.580858
# 8       15            86.416667
# 9       16            86.666667
# 10      18            82.561404
# 11      19            83.854167
# 12      20            71.504274
# 13      21            66.708333
# 14      23            71.816794

# %%
dfg=dd.groupby(['Sex', 'Education', 'Cities'])['Duration in minutes'].mean().reset_index()
dfg
# Out:
#    Sex Education        Cities  Duration in minutes
# 0    F  Graduate      Auckland            51.000000
# 1    F  Graduate        Dallas            73.000000
# 2    F  Graduate      New York            80.333333
# 3    F  Graduate       NewPort            72.666667
# 4    F  Graduate  San Franisco            46.333333
# 5    F       HSC      Auckland            56.733333
# 6    F       HSC        Dallas            65.559140
# 7    F       HSC      New York            84.532934
# 8    F       HSC       NewPort            68.352941
# 9    F       HSC  San Franisco            97.846154
# 10   F        PG      Auckland           113.333333
# 11   F        PG        Dallas            90.333333
# 12   F        PG      New York            92.000000
# 13   F       SSC      Auckland            98.309524
# 14   F       SSC        Dallas            83.869565
# 15   F       SSC      New York            72.350877
# 16   F       SSC       NewPort            79.051282
# 17   F       SSC  San Franisco            62.030303
# 18   M  Graduate      Auckland            63.500000
# 19   M  Graduate        Dallas           103.555556
# 20   M  Graduate      New York            50.000000
# 21   M  Graduate  San Franisco            73.000000
# 22   M       HSC      Auckland            53.690476
# 23   M       HSC        Dallas            84.653846
# 24   M       HSC      New York            85.964539
# 25   M       HSC       NewPort            74.541667
# 26   M       HSC  San Franisco            91.666667
# 27   M        PG        Dallas            50.611111
# 28   M        PG      New York            96.750000
# 29   M        PG       NewPort           107.000000
# 30   M        PG  San Franisco            71.000000
# 31   M       SSC      Auckland            74.842105
# 32   M       SSC        Dallas            71.854167
# 33   M       SSC      New York            79.874214
# 34   M       SSC       NewPort            65.400000
# 35   M       SSC  San Franisco            86.555556

# %%
sns.barplot(x='Sex', y='Duration in minutes', hue='Education', data=dfg)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Duration in minutes'>

# %%
corr=dd.corr()
corr
# Out:
#                            HH  INDIVIDUAL_ID    WEIGHT  Age_in_years  \
# HH                   1.000000       0.002834 -0.080451     -0.015166
# INDIVIDUAL_ID        0.002834       1.000000  0.038904     -0.001282
# WEIGHT              -0.080451       0.038904  1.000000     -0.013212
# Age_in_years        -0.015166      -0.001282 -0.013212      1.000000
# Blocks              -0.070539       0.030996  0.031213      0.050210
# Duration in minutes  0.035464      -0.026562  0.035149      0.215574
# CH1                 -0.004599      -0.030811 -0.021407      0.063344
# CH3                  0.011769       0.010497 -0.005057      0.080361
# CH4                  0.047275       0.046568 -0.047501      0.084540
# CH5                  0.037782      -0.031752  0.027738      0.148536
# CH2                  0.042558       0.018534  0.062666      0.100082
#
#                        Blocks  Duration in minutes       CH1       CH3  \
# HH                  -0.070539             0.035464 -0.004599  0.011769
# INDIVIDUAL_ID        0.030996            -0.026562 -0.030811  0.010497
# WEIGHT               0.031213             0.035149 -0.021407 -0.005057
# Age_in_years         0.050210             0.215574  0.063344  0.080361
# Blocks               1.000000            -0.039349 -0.042026  0.014261
# Duration in minutes -0.039349             1.000000  0.209200  0.184053
# CH1                 -0.042026             0.209200  1.000000 -0.145338
# CH3                  0.014261             0.184053 -0.145338  1.000000
# CH4                 -0.032411             0.211232 -0.123378 -0.110171
# CH5                 -0.043796             0.250260 -0.153592 -0.159872
# CH2                  0.029494             0.264524 -0.148133 -0.127212
#
#                           CH4       CH5       CH2
# HH                   0.047275  0.037782  0.042558
# INDIVIDUAL_ID        0.046568 -0.031752  0.018534
# WEIGHT              -0.047501  0.027738  0.062666
# Age_in_years         0.084540  0.148536  0.100082
# Blocks              -0.032411 -0.043796  0.029494
# Duration in minutes  0.211232  0.250260  0.264524
# CH1                 -0.123378 -0.153592 -0.148133
# CH3                 -0.110171 -0.159872 -0.127212
# CH4                  1.000000 -0.164907 -0.157246
# CH5                 -0.164907  1.000000 -0.103006
# CH2                 -0.157246 -0.103006  1.000000

# %%
# Let's get some information about our target feature
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Duration in minutes')
sns.distplot(dd['Duration in minutes'])

plt.subplot(1,2,2)
plt.title('Duration in minutes')

sns.boxplot(y=dd['Duration in minutes'])

plt.show()
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Calculate the quartiles and IQR
Q1 = np.percentile(dd["Duration in minutes"], 25)
Q3 = np.percentile(dd["Duration in minutes"], 75)
IQR = Q3 - Q1

# Calculate the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify the outliers
outliers = dd[(dd["Duration in minutes"] < lower_bound) | (dd["Duration in minutes"] > upper_bound)]
outliers
# # # Remove the outliers from the data
# # clean_data = dd[(dd["Duration in minutes"] >= lower_bound) & (dd["Duration in minutes"] <= upper_bound)]
# Out:
#        HH  INDIVIDUAL_ID       WEIGHT  Age_in_years Sex Education  \
# 31   9788              1  8340.160180            51   M       HSC
# 95   7958              5  6490.382370            51   F       HSC
# 104  9857              3  3127.801563            67   F       SSC
# 155  8684              5  7295.133403            31   F       HSC
# 174  5950              1  2990.551965            49   M       SSC
# 195  9587              1  1261.785361            46   F       HSC
# 212  9541              1  1337.572157            66   M       HSC
# 301  9729              2  7219.219130            31   F  Graduate
# 312  5733              2  3714.895931            65   M       SSC
# 355  9552              2  4978.719736            57   M       HSC
# 412  5458              2  3757.996913            26   F       SSC
# 482  6009              5  5505.729130            52   M       HSC
# 523  5153              2  7346.853146            52   F       SSC
# 31   9788              1  8340.160180            51   M       HSC
# 63   9060              3  8561.934218            44   M       SSC
# 155  8684              5  7295.133403            31   F       HSC
# 202  5532              3  9527.778830            37   F       SSC
# 270  7277              2  9058.814636            17   M       SSC
# 310  7995              4  9268.854462            43   M       HSC
# 321  7324              2  4928.051248            43   M        PG
# 373  9952              5  1151.035526            53   M        PG
# 455  7032              4  3658.556349            50   F       SSC
# 468  6569              1  8981.536167            80   F       SSC
# 523  5153              2  7346.853146            52   F       SSC
# 33   9082              4  3723.675836            44   F       HSC
# 38   6750              3  8433.034710            66   M  Graduate
# 63   9060              3  8561.934218            44   M       SSC
# 67   5886              2  8813.672639            66   M       HSC
# 104  9857              3  3127.801563            67   F       SSC
# 136  5356              4  9233.099641            46   M       SSC
# 155  8684              5  7295.133403            31   F       HSC
# 161  6961              2  8282.403776            46   F       HSC
# 174  5950              1  2990.551965            49   M       SSC
# 195  9587              1  1261.785361            46   F       HSC
# 222  7668              5  2720.483463            56   F       HSC
# 270  7277              2  9058.814636            17   M       SSC
# 319  9720              5  5363.488918            43   M       SSC
# 321  7324              2  4928.051248            43   M        PG
# 347  9188              3  8751.968368            50   M       HSC
# 355  9552              2  4978.719736            57   M       HSC
# 425  9401              3  4687.926950            67   M       HSC
# 455  7032              4  3658.556349            50   F       SSC
# 485  9396              5  9162.370784            60   M       SSC
# 523  5153              2  7346.853146            52   F       SSC
#
#            Cities  Blocks  Duration in minutes  CH1  CH3  CH4  CH5  CH2
# 31       New York       2                  273    0    1    1    1    0
# 95       New York       3                  230    0    0    1    2    0
# 104      Auckland       2                  197    0    0    1    2    0
# 155        Dallas       4                  221    0    1    1    1    1
# 174      New York      12                  240    0    1    1    0    2
# 195      New York       2                  236    1    0    3    0    0
# 212        Dallas      13                  205    0    1    0    1    2
# 301      New York       3                  196    0    0    2    1    0
# 312      New York       3                  242    2    0    1    0    1
# 355      New York      13                  220    1    0    0    1    2
# 412      Auckland      20                  230    1    1    0    0    1
# 482        Dallas       4                  215    0    0    0    2    1
# 523      Auckland      13                  241    0    0    0    3    1
# 31       New York       2                  201    0    1    0    0    2
# 63       New York      19                  243    1    0    0    0    3
# 155        Dallas       4                  307    1    2    0    0    1
# 202      Auckland      13                  201    1    1    0    1    0
# 270      New York       2                  271    2    0    0    1    0
# 310        Dallas      13                  204    0    0    0    0    3
# 321      New York      12                  215    0    1    1    1    0
# 373       NewPort      13                  208    1    0    0    1    1
# 455      New York       5                  251    0    1    1    2    0
# 468       NewPort      12                  206    2    0    0    0    1
# 523      Auckland      13                  301    1    0    1    1    1
# 33       New York       2                  223    2    0    0    0    2
# 38         Dallas      13                  255    0    0    1    1    1
# 63       New York      19                  196    0    0    2    1    1
# 67       New York       2                  222    1    2    0    0    0
# 104      Auckland       2                  233    0    1    0    2    0
# 136      New York       2                  209    2    0    0    0    1
# 155        Dallas       4                  226    0    0    0    2    2
# 161  San Franisco       8                  229    1    0    1    1    0
# 174      New York      12                  241    1    0    0    1    2
# 195      New York       2                  206    3    1    0    0    0
# 222      New York      13                  226    0    2    1    0    1
# 270      New York       2                  254    0    2    0    0    1
# 319      New York       9                  217    1    1    0    1    0
# 321      New York      12                  239    0    2    0    0    1
# 347  San Franisco       9                  238    1    1    0    1    0
# 355      New York      13                  205    1    1    0    2    0
# 425       NewPort      12                  287    0    2    1    0    1
# 455      New York       5                  277    1    0    2    0    1
# 485      Auckland       5                  219    1    1    0    0    1
# 523      Auckland      13                  212    0    1    0    2    1

# %%
dd["Duration in minutes"].skew()
# Out:
# 0.9283578144636668

# %% [raw]
# Duration in minutes is positive skewed

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Age_in_years')
sns.distplot(dd['Age_in_years'])

plt.subplot(1,2,2)
plt.title('Age_in_years')
sns.boxplot(y=dd['Age_in_years'])

plt.show()

dd["Age_in_years"].skew()

# Identify the outliers
Q1 = np.percentile(dd["Age_in_years"], 25)
Q3 = np.percentile(dd["Age_in_years"], 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = dd[(dd["Age_in_years"] < lower_bound) | (dd["Age_in_years"] > upper_bound)]
outliers
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Empty DataFrame
# Columns: [HH, INDIVIDUAL_ID, WEIGHT, Age_in_years, Sex, Education, Cities, Blocks, Duration in minutes, CH1, CH3, CH4, CH5, CH2]
# Index: []

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('WEIGHT')
sns.distplot(dd['WEIGHT'])

plt.subplot(1,2,2)
plt.title('WEIGHT')
sns.boxplot(y=dd['WEIGHT'])

plt.show()

dd["WEIGHT"].skew()

# Identify the outliers
Q1 = np.percentile(dd["WEIGHT"], 25)
Q3 = np.percentile(dd["WEIGHT"], 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = dd[(dd["WEIGHT"] < lower_bound) | (dd["WEIGHT"] > upper_bound)]
outliers
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Empty DataFrame
# Columns: [HH, INDIVIDUAL_ID, WEIGHT, Age_in_years, Sex, Education, Cities, Blocks, Duration in minutes, CH1, CH3, CH4, CH5, CH2]
# Index: []

# %%
dd.columns
# Out:
# Index(['HH', 'INDIVIDUAL_ID', 'WEIGHT', 'Age_in_years', 'Sex', 'Education',
#        'Cities', 'Blocks', 'Duration in minutes', 'CH1', 'CH3', 'CH4', 'CH5',
#        'CH2'],
#       dtype='object')

# %%
# Let's get some information about our target feature
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Blocks')
sns.distplot(dd['Blocks'])

plt.subplot(1,2,2)
plt.title('Blocks')
sns.boxplot(y=dd['Blocks'])

plt.show()

dd["Blocks"].skew()

# Identify the outliers
Q1 = np.percentile(dd["Blocks"], 25)
Q3 = np.percentile(dd["Blocks"], 75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = dd[(dd["Blocks"] < lower_bound) | (dd["Blocks"] > upper_bound)]
outliers
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Empty DataFrame
# Columns: [HH, INDIVIDUAL_ID, WEIGHT, Age_in_years, Sex, Education, Cities, Blocks, Duration in minutes, CH1, CH3, CH4, CH5, CH2]
# Index: []

# %%
d5=dd.copy()

# %% [markdown]
# ## Channel performance matrix:

# %%
Viewership_data_day2
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-02  6283              4                    7      CH4
# 1   2022-12-02  6283              1                   97      CH1
# 2   2022-12-02  6283              4                   99      CH1
# 3   2022-12-02  6283              5                   69      Ch2
# 4   2022-12-02  6658              2                   18      CH1
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-02  5153              2                   86      CH4
# 797 2022-12-02  5153              2                   75      CH1
# 798 2022-12-02  5153              2                   53      CH5
# 799 2022-12-02  5153              2                   87      Ch2
# 800 2022-12-02  5153              3                   40      CH4
#
# [801 rows x 5 columns]

# %%
Viewership_data_day2 = Viewership_data_day2.rename(columns={'Duration_in_minutes': 'Duration in minutes'})

# %%
day=pd.concat([Viewership_data_day1,Viewership_data_day2,Viewership_data_day3],axis=0)
day
# Out:
#           Date    HH  INDIVIDUAL_ID  Duration in minutes Channels
# 0   2022-12-01  6283              4                   66      CH3
# 1   2022-12-01  6283              1                   61      CH5
# 2   2022-12-01  6283              4                    1      CH1
# 3   2022-12-01  6283              5                   97      Ch2
# 4   2022-12-01  6658              2                   38      Ch2
# ..         ...   ...            ...                  ...      ...
# 796 2022-12-03  5153              2                   71      CH5
# 797 2022-12-03  5153              2                   54      CH5
# 798 2022-12-03  5153              2                   34      CH3
# 799 2022-12-03  5153              2                   53      Ch2
# 800 2022-12-03  5153              3                   25      CH3
#
# [2403 rows x 5 columns]

# %%
day_data=pd.merge(day,data,on=["HH","INDIVIDUAL_ID"])

# %%
day_data
# Out:
#            Date    HH  INDIVIDUAL_ID  Duration in minutes Channels  \
# 0    2022-12-01  6283              4                   66      CH3
# 1    2022-12-01  6283              4                    1      CH1
# 2    2022-12-02  6283              4                    7      CH4
# 3    2022-12-02  6283              4                   99      CH1
# 4    2022-12-03  6283              4                   54      CH5
# ...         ...   ...            ...                  ...      ...
# 2398 2022-12-03  5153              2                   34      CH3
# 2399 2022-12-03  5153              2                   53      Ch2
# 2400 2022-12-01  5153              3                   86      CH4
# 2401 2022-12-02  5153              3                   40      CH4
# 2402 2022-12-03  5153              3                   25      CH3
#
#            WEIGHT  Age_in_years Sex Education  HH ID    Cities  Blocks
# 0     4844.772198            50   M       SSC   6283    Dallas       4
# 1     4844.772198            50   M       SSC   6283    Dallas       4
# 2     4844.772198            50   M       SSC   6283    Dallas       4
# 3     4844.772198            50   M       SSC   6283    Dallas       4
# 4     4844.772198            50   M       SSC   6283    Dallas       4
# ...           ...           ...  ..       ...    ...       ...     ...
# 2398  7346.853146            52   F       SSC   5153  Auckland      13
# 2399  7346.853146            52   F       SSC   5153  Auckland      13
# 2400  8639.334048             4   M       HSC   5153  Auckland      13
# 2401  8639.334048             4   M       HSC   5153  Auckland      13
# 2402  8639.334048             4   M       HSC   5153  Auckland      13
#
# [2403 rows x 12 columns]

# %%
day_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2403 entries, 0 to 2402
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 2403 non-null   datetime64[ns]
#  1   HH                   2403 non-null   int64
#  2   INDIVIDUAL_ID        2403 non-null   int64
#  3   Duration in minutes  2403 non-null   int64
#  4   Channels             2403 non-null   object
#  5   WEIGHT               2403 non-null   float64
#  6   Age_in_years         2403 non-null   int64
#  7   Sex                  2403 non-null   object
#  8   Education            2403 non-null   object
#  9   HH ID                2403 non-null   int64
#  10  Cities               2403 non-null   object
#  11  Blocks               2403 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(4)
# memory usage: 244.1+ KB

# %%
d1=day_data.groupby(['Channels'])['Duration in minutes'].mean().reset_index()
d1
# Out:
#   Channels  Duration in minutes
# 0      CH1            48.673387
# 1      CH3            50.556468
# 2      CH4            51.162281
# 3      CH5            51.184411
# 4      Ch2            53.264840

# %%
# Create a bar chart
fig, ax = plt.subplots(figsize=(8,6))
ax.bar(d1['Channels'], d1['Duration in minutes'], color='b')

# Add labels and titles
ax.set_xlabel('Channels')
ax.set_ylabel('Average duration in minutes')
ax.set_title('Average duration by channel')

plt.show()

# %%
d2=day_data.groupby(['Channels','Sex'])['Duration in minutes'].mean().reset_index()
d2
# Out:
#   Channels Sex  Duration in minutes
# 0      CH1   F            48.675105
# 1      CH1   M            48.671815
# 2      CH3   F            48.348018
# 3      CH3   M            52.484615
# 4      CH4   F            49.808411
# 5      CH4   M            52.359504
# 6      CH5   F            51.895349
# 7      CH5   M            50.500000
# 8      Ch2   F            52.255208
# 9      Ch2   M            54.052846

# %%
# Create a stacked bar chart
fig, ax = plt.subplots(figsize=(8,6))

# Define the x-axis and bar widths
channels = d2['Channels'].unique()
n_channels = len(channels)
bar_width = 0.8

# Create the bars for male and female
male_means = d2[d2['Sex']=='M']['Duration in minutes']
female_means = d2[d2['Sex']=='F']['Duration in minutes']
x = range(n_channels)

ax.bar(x, male_means, width=bar_width, color='b', label='Male')
ax.bar(x, female_means, width=bar_width, bottom=male_means, color='r', label='Female')

# Add labels and titles
ax.set_xticks(range(n_channels))
ax.set_xticklabels(channels)
ax.set_xlabel('Channels')
ax.set_ylabel('Average duration in minutes')
ax.set_title('Average duration by channel and sex')
ax.legend()

plt.show()

# %%
d3=day_data.groupby(['Channels','Cities'])['Duration in minutes'].mean().reset_index()
d3
# Out:
#    Channels        Cities  Duration in minutes
# 0       CH1      Auckland            44.815789
# 1       CH1        Dallas            48.048780
# 2       CH1      New York            47.248889
# 3       CH1       NewPort            48.018868
# 4       CH1  San Franisco            58.824561
# 5       CH3      Auckland            50.526316
# 6       CH3        Dallas            50.565574
# 7       CH3      New York            50.942708
# 8       CH3       NewPort            50.116667
# 9       CH3  San Franisco            49.714286
# 10      CH4      Auckland            53.754717
# 11      CH4        Dallas            50.535088
# 12      CH4      New York            51.507937
# 13      CH4       NewPort            52.463415
# 14      CH4  San Franisco            48.033898
# 15      CH5      Auckland            50.746269
# 16      CH5        Dallas            55.283784
# 17      CH5      New York            49.101523
# 18      CH5       NewPort            45.272727
# 19      CH5  San Franisco            53.864407
# 20      Ch2      Auckland            56.307692
# 21      Ch2        Dallas            53.675676
# 22      Ch2      New York            55.704663
# 23      Ch2       NewPort            46.714286
# 24      Ch2  San Franisco            42.545455

# %%
# Create a pivot table with Channels as rows and Cities as columns
pivot_table = d3.pivot(index='Channels', columns='Cities', values='Duration in minutes')
# Create a heatmap
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(pivot_table, cmap='coolwarm', annot=True, fmt='.2f')

# Add labels and titles
ax.set_xlabel('Cities')
ax.set_ylabel('Channels')
ax.set_title('Average duration by channel and city')

plt.show()

# %%
 day_data.groupby(['Channels','Cities'])['Duration in minutes'].mean().reset_index()
# Out:
#    Channels        Cities  Duration in minutes
# 0       CH1      Auckland            44.815789
# 1       CH1        Dallas            48.048780
# 2       CH1      New York            47.248889
# 3       CH1       NewPort            48.018868
# 4       CH1  San Franisco            58.824561
# 5       CH3      Auckland            50.526316
# 6       CH3        Dallas            50.565574
# 7       CH3      New York            50.942708
# 8       CH3       NewPort            50.116667
# 9       CH3  San Franisco            49.714286
# 10      CH4      Auckland            53.754717
# 11      CH4        Dallas            50.535088
# 12      CH4      New York            51.507937
# 13      CH4       NewPort            52.463415
# 14      CH4  San Franisco            48.033898
# 15      CH5      Auckland            50.746269
# 16      CH5        Dallas            55.283784
# 17      CH5      New York            49.101523
# 18      CH5       NewPort            45.272727
# 19      CH5  San Franisco            53.864407
# 20      Ch2      Auckland            56.307692
# 21      Ch2        Dallas            53.675676
# 22      Ch2      New York            55.704663
# 23      Ch2       NewPort            46.714286
# 24      Ch2  San Franisco            42.545455

# %%
d5=day_data.groupby(['Channels','Education'])['Duration in minutes'].mean().reset_index()
d5
# Out:
#    Channels Education  Duration in minutes
# 0       CH1  Graduate            41.136364
# 1       CH1       HSC            46.021739
# 2       CH1        PG            46.739130
# 3       CH1       SSC            52.384615
# 4       CH3  Graduate            46.857143
# 5       CH3       HSC            49.928870
# 6       CH3        PG            55.076923
# 7       CH3       SSC            50.961538
# 8       CH4  Graduate            48.473684
# 9       CH4       HSC            50.976526
# 10      CH4        PG            64.200000
# 11      CH4       SSC            50.660287
# 12      CH5  Graduate            59.652174
# 13      CH5       HSC            52.054167
# 14      CH5        PG            48.240000
# 15      CH5       SSC            49.798319
# 16      Ch2  Graduate            59.666667
# 17      Ch2       HSC            52.881443
# 18      Ch2        PG            54.800000
# 19      Ch2       SSC            52.910798

# %%
d6=day_data.groupby(['Channels','Education','Sex'])['Duration in minutes'].mean().reset_index()
d6
# Out:
#    Channels Education Sex  Duration in minutes
# 0       CH1  Graduate   F            38.727273
# 1       CH1  Graduate   M            43.545455
# 2       CH1       HSC   F            45.053846
# 3       CH1       HSC   M            47.280000
# 4       CH1        PG   F            50.111111
# 5       CH1        PG   M            44.571429
# 6       CH1       SSC   F            55.195402
# 7       CH1       SSC   M            50.559701
# 8       CH3  Graduate   F            35.500000
# 9       CH3  Graduate   M            51.400000
# 10      CH3       HSC   F            47.412214
# 11      CH3       HSC   M            52.981481
# 12      CH3        PG   F            53.000000
# 13      CH3        PG   M            56.000000
# 14      CH3       SSC   F            49.976190
# 15      CH3       SSC   M            51.629032
# 16      CH4  Graduate   F            55.500000
# 17      CH4  Graduate   M            43.363636
# 18      CH4       HSC   F            49.934959
# 19      CH4       HSC   M            52.400000
# 20      CH4        PG   F            82.800000
# 21      CH4        PG   M            54.900000
# 22      CH4       SSC   F            46.910256
# 23      CH4       SSC   M            52.893130
# 24      CH5  Graduate   F            66.333333
# 25      CH5  Graduate   M            55.357143
# 26      CH5       HSC   F            51.612903
# 27      CH5       HSC   M            52.525862
# 28      CH5        PG   F            50.600000
# 29      CH5        PG   M            46.666667
# 30      CH5       SSC   F            51.182609
# 31      CH5       SSC   M            48.504065
# 32      Ch2  Graduate   F            68.285714
# 33      Ch2  Graduate   M            55.357143
# 34      Ch2       HSC   F            50.271739
# 35      Ch2       HSC   M            55.235294
# 36      Ch2        PG   F            45.250000
# 37      Ch2        PG   M            61.166667
# 38      Ch2       SSC   F            53.359551
# 39      Ch2       SSC   M            52.588710

# %%
# Create a pivot table with Education as rows, Channels as columns, and Sex as values
pivot_table = d6.pivot_table(index='Education', columns=['Channels', 'Sex'], values='Duration in minutes')

# Create a stacked bar chart
fig, ax = plt.subplots(figsize=(10,8))
pivot_table.plot(kind='bar', stacked=True, ax=ax)

# Add labels and titles
ax.set_xlabel('Education')
ax.set_ylabel('Average duration in minutes')
ax.set_title('Average duration by channel, education level and sex')

plt.show()
